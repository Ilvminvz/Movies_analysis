# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
column_names = ['Country','Description','Points','Points','Price',
               'Province','Region_1','Region_2','Variety','Winery']

# %%
reviews_df = pd.read_csv('C:\\Users\\dell\\Documents\\Python-Scripts\\Untitled-Folder\\Pandas\\winemag-data_first150k.csv',sep=',',header=1,
                        names=column_names,index_col=0)

# %%
reviews_df.shape
# Out:
# (150929, 10)

# %%
reviews_df
# Out:
#             Country                                        Description  \
# 1             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                US  Mac Watson honors the memory of a wine once ma...
# 3                US  This spent 20 months in 30% new French oak, an...
# 4            France  This is the top wine from La Bégude, named aft...
# 5             Spain  Deep, dense and pure from the opening bell, th...
# 6             Spain  Slightly gritty black-fruit aromas include a s...
# 7             Spain  Lush cedary black-fruit aromas are luxe and of...
# 8                US  This re-named vineyard was formerly bottled as...
# 9                US  The producer sources from two blocks of the vi...
# 10            Italy  Elegance, complexity and structure come togeth...
# 11               US  From 18-year-old vines, this supple well-balan...
# 12               US  A standout even in this terrific lineup of 201...
# ...

# %%
reviews_df.head(10)
# Out:
#    Country                                        Description  \
# 1    Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2       US  Mac Watson honors the memory of a wine once ma...
# 3       US  This spent 20 months in 30% new French oak, an...
# 4   France  This is the top wine from La Bégude, named aft...
# 5    Spain  Deep, dense and pure from the opening bell, th...
# 6    Spain  Slightly gritty black-fruit aromas include a s...
# 7    Spain  Lush cedary black-fruit aromas are luxe and of...
# 8       US  This re-named vineyard was formerly bottled as...
# 9       US  The producer sources from two blocks of the vi...
# 10   Italy  Elegance, complexity and structure come togeth...
#
#                                   Points  Points.1  Price            Province  \
# 1   Carodorum Selección Especial Reserva        96  110.0      Northern Spain
# 2          Special Selected Late Harvest        96   90.0          California
# ...

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150929 entries, 1 to 150929
# Data columns (total 10 columns):
# Country        150924 non-null object
# Description    150929 non-null object
# Points         105194 non-null object
# Points.1       150929 non-null int64
# Price          137234 non-null float64
# Province       150924 non-null object
# Region_1       125869 non-null object
# Region_2       60952 non-null object
# Variety        150929 non-null object
# Winery         150929 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 12.7+ MB

# %%
reviews_df.info
# Out:
# <bound method DataFrame.info of             Country                                        Description  \
# 1             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                US  Mac Watson honors the memory of a wine once ma...
# 3                US  This spent 20 months in 30% new French oak, an...
# 4            France  This is the top wine from La Bégude, named aft...
# 5             Spain  Deep, dense and pure from the opening bell, th...
# 6             Spain  Slightly gritty black-fruit aromas include a s...
# 7             Spain  Lush cedary black-fruit aromas are luxe and of...
# 8                US  This re-named vineyard was formerly bottled as...
# 9                US  The producer sources from two blocks of the vi...
# 10            Italy  Elegance, complexity and structure come togeth...
# 11               US  From 18-year-old vines, this supple well-balan...
# 12               US  A standout even in this terrific lineup of 201...
# ...

# %%
reviews_df.isnull()
# Out:
#         Country  Description  Points  Points.1  Price  Province  Region_1  \
# 1         False        False   False     False  False     False     False
# 2         False        False   False     False  False     False     False
# 3         False        False   False     False  False     False     False
# 4         False        False   False     False  False     False     False
# 5         False        False   False     False  False     False     False
# 6         False        False   False     False  False     False     False
# 7         False        False   False     False  False     False     False
# 8         False        False   False     False  False     False     False
# 9         False        False   False     False  False     False     False
# 10        False        False   False     False  False     False     False
# 11        False        False   False     False  False     False     False
# 12        False        False   False     False  False     False     False
# ...

# %%
reviews_df.isnull().any() #.any() is used for columns
# Out:
# Country         True
# Description    False
# Points          True
# Points.1       False
# Price           True
# Province        True
# Region_1        True
# Region_2        True
# Variety        False
# Winery         False
# dtype: bool

# %%
reviews_df.loc[1:reviews_df.shape[0]].isnull()
# Out:
#         Country  Description  Points  Points.1  Price  Province  Region_1  \
# 1         False        False   False     False  False     False     False
# 2         False        False   False     False  False     False     False
# 3         False        False   False     False  False     False     False
# 4         False        False   False     False  False     False     False
# 5         False        False   False     False  False     False     False
# 6         False        False   False     False  False     False     False
# 7         False        False   False     False  False     False     False
# 8         False        False   False     False  False     False     False
# 9         False        False   False     False  False     False     False
# 10        False        False   False     False  False     False     False
# 11        False        False   False     False  False     False     False
# 12        False        False   False     False  False     False     False
# ...

# %%
reviews_df.isnull().sum()
# Out:
# Country            5
# Description        0
# Points         45735
# Points.1           0
# Price          13695
# Province           5
# Region_1       25060
# Region_2       89977
# Variety            0
# Winery             0
# dtype: int64

# %%
reviews_df[reviews_df['Country'].isnull()]
# Out:
#        Country                                        Description  \
# 1133       NaN  Delicate white flowers and a spin of lemon pee...
# 1440       NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226      NaN  From first sniff to last, the nose never makes...
# 113016     NaN  From first sniff to last, the nose never makes...
# 135696     NaN  From first sniff to last, the nose never makes...
#
#               Points  Points.1  Price Province Region_1 Region_2     Variety  \
# 1133       Askitikos        90   17.0      NaN      NaN      NaN   Assyrtiko
# 1440            Shah        90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz        81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz        81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz        81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            Winery
# 1133     Tsililis
# 1440    Büyülübağ
# 68226     Chilcas
# 113016    Chilcas
# ...

# %%
reviews_df = reviews_df.dropna(subset=['Country'])
reviews_df
# Out:
#             Country                                        Description  \
# 1             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                US  Mac Watson honors the memory of a wine once ma...
# 3                US  This spent 20 months in 30% new French oak, an...
# 4            France  This is the top wine from La Bégude, named aft...
# 5             Spain  Deep, dense and pure from the opening bell, th...
# 6             Spain  Slightly gritty black-fruit aromas include a s...
# 7             Spain  Lush cedary black-fruit aromas are luxe and of...
# 8                US  This re-named vineyard was formerly bottled as...
# 9                US  The producer sources from two blocks of the vi...
# 10            Italy  Elegance, complexity and structure come togeth...
# 11               US  From 18-year-old vines, this supple well-balan...
# 12               US  A standout even in this terrific lineup of 201...
# ...

# %%
reviews_df[reviews_df['Country'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Country, Description, Points, Points.1, Price, Province, Region_1, Region_2, Variety, Winery]
# Index: []

# %%
reviews_df.shape #you can see a drop in the number of rows from 150929 to 150924
# Out:
# (150924, 10)

# %%
#######The above is called data cleaning

# %%
null_prices = reviews_df['Price'].isnull().sum()
total_prices = reviews_df.shape[0]
percentage = (total_prices - null_prices) / total_prices * 100
percentage
# Out:
# 90.92589647769739

# %%
reviews_df = reviews_df.dropna(subset=['Price']) #drop all the null values of 'Price'

# %%
reviews_df
# Out:
#             Country                                        Description  \
# 1             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                US  Mac Watson honors the memory of a wine once ma...
# 3                US  This spent 20 months in 30% new French oak, an...
# 4            France  This is the top wine from La Bégude, named aft...
# 5             Spain  Deep, dense and pure from the opening bell, th...
# 6             Spain  Slightly gritty black-fruit aromas include a s...
# 7             Spain  Lush cedary black-fruit aromas are luxe and of...
# 8                US  This re-named vineyard was formerly bottled as...
# 9                US  The producer sources from two blocks of the vi...
# 10            Italy  Elegance, complexity and structure come togeth...
# 11               US  From 18-year-old vines, this supple well-balan...
# 12               US  A standout even in this terrific lineup of 201...
# ...

# %%
reviews_df.isnull().sum()
# Out:
# Country            0
# Description        0
# Points         42311
# Points.1           0
# Price              0
# Province           0
# Region_1       22837
# Region_2       76526
# Variety            0
# Winery             0
# dtype: int64

# %%
reviews_df.std()
# Out:
# Points.1     3.221507
# Price       36.319116
# dtype: float64

# %%
reviews_df[reviews_df.duplicated('Country')]
# Out:
#        Country                                        Description  \
# 3           US  This spent 20 months in 30% new French oak, an...
# 5        Spain  Deep, dense and pure from the opening bell, th...
# 6        Spain  Slightly gritty black-fruit aromas include a s...
# 7        Spain  Lush cedary black-fruit aromas are luxe and of...
# 8           US  This re-named vineyard was formerly bottled as...
# 9           US  The producer sources from two blocks of the vi...
# 11          US  From 18-year-old vines, this supple well-balan...
# 12          US  A standout even in this terrific lineup of 201...
# 13      France  This wine is in peak condition. The tannins an...
# 14          US  With its sophisticated mix of mineral, acid an...
# 15          US  First made in 2006, this succulent luscious Ch...
# 16          US  This blockbuster, powerhouse of a wine suggest...
# 17       Spain  Nicely oaked blackberry, licorice, vanilla and...
# ...

# %%
reviews_df['Country'].nunique()
# Out:
# 46

# %%
reviews_df['Price'].nunique()
# Out:
# 357

# %%
reviews_df['Country'].value_counts() #number of times a country appeared in the dataset
# Out:
# US                        62138
# Italy                     18784
# France                    14785
# Spain                      8160
# Chile                      5766
# Argentina                  5587
# Australia                  4894
# Portugal                   4176
# New Zealand                3070
# Austria                    2483
# Germany                    2347
# South Africa               2237
# Greece                      872
# Israel                      610
# Hungary                     230
# Canada                      194
# Romania                     139
# Uruguay                      85
# Croatia                      83
# Slovenia                     81
# Bulgaria                     77
# Moldova                      71
# Mexico                       63
# Turkey                       50
# Georgia                      43
# Lebanon                      37
# Cyprus                       31
# Brazil                       25
# Macedonia                    16
# ...

# %%
reviews_df[reviews_df['Price'] == reviews_df['Price'].max()]['Country'] #Finding the 'Country' with the highest 'Price'
# Out:
# 34920    France
# Name: Country, dtype: object

# %%
reviews_df['Price'].mean() #Finding the average of the Price
# Out:
# 33.13054820774035

# %%
min_price = reviews_df['Price'].min()
min_price
# Out:
# 4.0

# %%
reviews_df[reviews_df['Price']== min_price]
# Out:
#           Country                                        Description  \
# 1858           US  Sweet and fruity, this canned wine feels soft ...
# 25645          US  There's a lot going on in this Merlot, which i...
# 34415       Spain  This opens with standard cherry and berry arom...
# 34682       Spain  Nice on the nose, this has a leafy note and a ...
# 36716   Argentina  Crimson in color but also translucent, with a ...
# 48655          US  There's a lot going on in this Merlot, which i...
# 73417     Romania  Notes of sun-dried hay and green flower highli...
# 80185          US  There's a lot going on in this Merlot, which i...
# 90546   Argentina  Clean as anyone should reasonably expect given...
# 91766   Argentina  Crimson in color but also translucent, with a ...
# 99045    Portugal  This is a ripe-fruited wine, rich with dried f...
# 102035      Spain  This opens with standard cherry and berry arom...
# 102332      Spain  Nice on the nose, this has a leafy note and a ...
# ...

# %%
reviews_df[reviews_df['Price']== min_price].shape
# Out:
# (18, 10)

# %%
reviews_df[reviews_df['Price']== min_price].shape[0]
# Out:
# 18

# %%
#Finding the top ten based on 'Variety'

reviews_df['Variety'].value_counts().max()
# Out:
# 13775

# %%
reviews_df['Variety'].value_counts()
# Out:
# Chardonnay                       13775
# Pinot Noir                       13625
# Cabernet Sauvignon               12670
# Red Blend                         9377
# Sauvignon Blanc                   6054
# Syrah                             5667
# Riesling                          5212
# Merlot                            4987
# Bordeaux-style Red Blend          4545
# Zinfandel                         3794
# Malbec                            3085
# Sangiovese                        2879
# White Blend                       2554
# Tempranillo                       2525
# Rosé                              2461
# Shiraz                            1945
# Sparkling Blend                   1820
# Portuguese Red                    1812
# Nebbiolo                          1529
# Rhône-style Red Blend             1455
# Cabernet Franc                    1310
# Corvina, Rondinella, Molinara     1292
# Pinot Gris                        1275
# Pinot Grigio                      1270
# ...

# %%
Top_ten = reviews_df['Variety'].value_counts()
Top_ten.head(10)
# Out:
# Chardonnay                  13775
# Pinot Noir                  13625
# Cabernet Sauvignon          12670
# Red Blend                    9377
# Sauvignon Blanc              6054
# Syrah                        5667
# Riesling                     5212
# Merlot                       4987
# Bordeaux-style Red Blend     4545
# Zinfandel                    3794
# Name: Variety, dtype: int64

# %%
#Create a dataframe having a dataset with Points which equals 100
perfect_score_df = reviews_df[reviews_df['Points.1'] == 100]

# %%
perfect_score_df
# Out:
#           Country                                        Description  \
# 2145       France  Full of ripe fruit, opulent and concentrated, ...
# 19354          US  In a stunning lineup of Cayuse Syrahs, the En ...
# 19355   Australia  Not a Cellar Selection in the traditional sens...
# 24151       Italy  A perfect wine from a classic vintage, the 200...
# 26296      France  A wine that has created its own universe. It h...
# 28954       Italy  This small, family-run estate in the heart of ...
# 41521       Italy  A perfect wine from a classic vintage, the 200...
# 51886      France  A wine that has created its own universe. It h...
# 78004       Italy  This small, family-run estate in the heart of ...
# 83536      France  A wine that has created its own universe. It h...
# 84034          US  In a stunning lineup of Cayuse Syrahs, the En ...
# 84035   Australia  Not a Cellar Selection in the traditional sens...
# 89399          US  Tasted in a flight of great and famous Napa wi...
# ...

# %%
plt.plot(reviews_df.index, reviews_df.Price)
plt.grid(True)
plt.show()

# %%
plt.plot(reviews_df.index[1:10], reviews_df.Price[1:10])
plt.grid(True)
plt.show()

# %%
reviews_df['Province'].value_counts().head(10).plot.pie()
plt.show()

# %%
import seaborn as sn
sn.countplot(reviews_df['Country'].head(20))
